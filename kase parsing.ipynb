# %%
import requests
from bs4 import BeautifulSoup
import csv
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import pandas as pd
import os
import pickle
import smtplib, ssl

# %%
df_test = pd.DataFrame()
links = []

# %%
from email.mime.text import MIMEText
import base64
from __future__ import print_function
import os.path
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.send']

def create_message(sender, to, subject, message_text):
  message = MIMEText(message_text)
  message['to'] = to
  message['from'] = sender
  message['subject'] = subject
  raw_message = base64.urlsafe_b64encode(message.as_string().encode("utf-8"))
  return {
    'raw': raw_message.decode("utf-8")
  }

def send_message(service, user_id, message):
  try:
    message = service.users().messages().send(userId=user_id, body=message).execute()
    print('Message Id: %s' % message['id'])
    return message
  except Exception as e:
    print('An error occurred: %s' % e)
    return None

kase_update = send_message(service=build('gmail', 'v1', credentials=Credentials.from_authorized_user_file('token.json', SCOPES)), user_id='sultan.python.tests@gmail.com', message=create_message('sultan.python.tests@gmail.com', 'sultann1997@gmail.com', 'Kase Update', 'Kase DataFrame has been updated'))
# Out:
# Message Id: 17a571b1c26509b2

# %%
URL = 'https://kase.kz/ru/documents/marketvaluation/'

if requests.get(URL).status_code == 200:
    print('Connected')
else:
    print("Could not connect into server")

soup = BeautifulSoup(requests.get(URL).text, features='html.parser')
items = soup.find_all('div', {'id':'a2021'})


def download_unzip(url, extract_to='.'):
    http_response = urlopen(url)
    zipfile = ZipFile(BytesIO(http_response.read()))
    zipfile.extractall(path=extract_to)
# links_file = open(r'C:\Users\Sultan\Downloads\Big Data downloads\links.pkl', 'rb')
# links = pickle.load(links_file)
# links_file.close()

for div in soup.find_all('div', {'id':'a2021'}):
    for li in div.find_all('li'):
        a = li.find('a')
        if a['href'].replace(r'/files/market_valuation/ru/2021/', '') in os.listdir(r'C:\Users\Sultan\Downloads\Big Data downloads\Kase zips check2'):
            pass
        else:
            # links.append(a['href'])
            url_zip = 'https://kase.kz/' + a['href']
            current_dir = os.path.abspath(r'C:\Users\Sultan\Downloads\Big Data downloads\Kase zips check2'+'\\'+a['href'].replace(r'/files/market_valuation/ru/2021/', ''))
            try: os.makedirs(current_dir)
            except FileExistsError:
                pass
            download_unzip(url_zip, current_dir)
            excel_file = [i for i in os.listdir(current_dir) if i.endswith('xlsx')]
            try: 
                temp_df = pd.read_excel(current_dir +'\\'+ excel_file[0], engine='openpyxl')
                headers = temp_df.iloc[1]
                temp_df = temp_df[3:]
                temp_df.columns = headers
                temp_df.drop(temp_df.columns[0], axis=1, inplace=True)
                temp_df['File'] = excel_file[0]
                df_test = df_test.append(temp_df)
                df_test.reset_index(drop=True, inplace=True)
                send_message(service=build('gmail', 'v1', credentials=Credentials.from_authorized_user_file('token.json', SCOPES)), user_id='sultan.python.tests@gmail.com', message=create_message('sultan.python.tests@gmail.com', 'sultann1997@gmail.com', 'Kase Update', 'Kase DataFrame has been updated'))
            except (IndexError, AttributeError):
                pass
# pickle.dump(links, open(r'C:\Users\Sultan\Downloads\Big Data downloads\links.pkl', 'wb'))
# Out:
# Connected
# Message Id: 17a57281dc224a25
# Message Id: 17a5729eee32ad7c
# Message Id: 17a5729f7c93491d
# Message Id: 17a5729fdfa57f06
# Message Id: 17a572a033528fa6
# Message Id: 17a572a0912746ed
# Message Id: 17a572a0e35e6caf
# Message Id: 17a572a13a8c903b
# Message Id: 17a572a18dfba3d2
# Message Id: 17a572a1e82fdb70
# Message Id: 17a572a245d5a789
# Message Id: 17a572a29aa93098
# Message Id: 17a572a2cf87da6b
# Message Id: 17a572a33d446792
# Message Id: 17a572a38c9e4a12
# Message Id: 17a572a3f6a53ea8
# Message Id: 17a572a4518747c1
# Message Id: 17a572a4a8c14a05
# Message Id: 17a572a50df51fee
# Message Id: 17a572a57b37faff
# Message Id: 17a572a5bf6a1680
# Message Id: 17a572a63b25aee2
# Message Id: 17a572a6a1956a12
# Message Id: 17a572a71ca14276
# Message Id: 17a572a779f98c39
# Message Id: 17a572a7aab9b603
# Message Id: 17a572a801b92b00
# Message Id: 17a572a8793bc88e
# Message Id: 17a572a8b3593eea
# Message Id: 17a572a901fd987c
# Message Id: 17a572a97f500b32
# Message Id: 17a572a9d36caca6

# %%
df_test
# Out:
# 1     Торговый код          ISIN              Вид ценной бумаги  \
# 0       ABK024_063  KZMJ00000636  государственные ценные бумаги
# 1       ABK119_006  KZMF00000069  государственные ценные бумаги
# 2       ABK131_021  KZMF00000218  государственные ценные бумаги
# 3       ABK143_032  KZMF00000325  государственные ценные бумаги
# 4       ABK143_033  KZMF00000333  государственные ценные бумаги
# ...            ...           ...                            ...
# 81667   ZKK131_012  KZMF00000127  государственные ценные бумаги
# 81668   ZKK143_013  KZMF00000135  государственные ценные бумаги
# 81669   ZKK143_044  KZMF00000440  государственные ценные бумаги
# 81670         ZNGR  KZ000A1CTM83                          акции
# 81671        ZNGRp  KZ000A1CTM91                          акции
#
# 1                          Краткое наименование эмитента Расчетная цена  \
# 0                             Акимат Актюбинской области            100
# 1                             Акимат Актюбинской области            100
# 2                             Акимат Актюбинской области            100
# 3                             Акимат Актюбинской области            100
# 4                             Акимат Актюбинской области            100
# ...                                                  ...            ...
# 81667               Акимат Западно-Казахстанской области            100
# 81668               Акимат Западно-Казахстанской области            100
# 81669               Акимат Западно-Казахстанской области            100
# 81670  АО "Казахский Республиканский Торговый Дом "ЗА...           0.01
# 81671  АО "Казахский Республиканский Торговый Дом "ЗА...            100
#
# 1     Расчетная грязная Доходность до погашения, % годовых Дней до погашения  \
# 0             100,08460                            0,35000               273
# 1             100,06780                            6,09000              3206
# 2             105,33750                            6,09000              3615
# 3             104,18530                            6,09000              4043
# 4             104,18530                            6,09000              4043
# ...                 ...                                ...               ...
# 81667         102,38920                            6,08000              3789
# 81668         101,23690                            6,09000              4217
# 81669         101,23690                            6,09000              4217
# 81670               NaN                                NaN               NaN
# 81671               NaN                                NaN               NaN
#
# 1     Единица измерения цены      Тип цены                   File
# 0             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 1             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 2             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 3             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 4             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# ...                      ...           ...                    ...
# 81667         Чистая цена в%  Индикативная  Price05_01_21(1).xlsx
# 81668         Чистая цена в%  Индикативная  Price05_01_21(1).xlsx
# 81669         Чистая цена в%  Индикативная  Price05_01_21(1).xlsx
# 81670                  Тенге  Индикативная  Price05_01_21(1).xlsx
# 81671                  Тенге  Индикативная  Price05_01_21(1).xlsx
#
# [81672 rows x 11 columns]

# %%
df_test.to_excel(r"C:\Users\Sultan\Downloads\Big Data downloads\my_excel.xls", engine='openpyxl')

# %%
# df_test.reset_index(drop=True).drop(df_test.columns[0], axis=1)
# Out:
# 1     Торговый код          ISIN              Вид ценной бумаги  \
# 0       ABK024_063  KZMJ00000636  государственные ценные бумаги
# 1       ABK119_006  KZMF00000069  государственные ценные бумаги
# 2       ABK131_021  KZMF00000218  государственные ценные бумаги
# 3       ABK143_032  KZMF00000325  государственные ценные бумаги
# 4       ABK143_033  KZMF00000333  государственные ценные бумаги
# ...            ...           ...                            ...
# 81667   ZKK131_012  KZMF00000127  государственные ценные бумаги
# 81668   ZKK143_013  KZMF00000135  государственные ценные бумаги
# 81669   ZKK143_044  KZMF00000440  государственные ценные бумаги
# 81670         ZNGR  KZ000A1CTM83                          акции
# 81671        ZNGRp  KZ000A1CTM91                          акции
#
# 1                          Краткое наименование эмитента Расчетная цена  \
# 0                             Акимат Актюбинской области            100
# 1                             Акимат Актюбинской области            100
# 2                             Акимат Актюбинской области            100
# 3                             Акимат Актюбинской области            100
# 4                             Акимат Актюбинской области            100
# ...                                                  ...            ...
# 81667               Акимат Западно-Казахстанской области            100
# 81668               Акимат Западно-Казахстанской области            100
# 81669               Акимат Западно-Казахстанской области            100
# 81670  АО "Казахский Республиканский Торговый Дом "ЗА...           0.01
# 81671  АО "Казахский Республиканский Торговый Дом "ЗА...            100
#
# 1     Расчетная грязная Доходность до погашения, % годовых Дней до погашения  \
# 0             100,08460                            0,35000               273
# 1             100,06780                            6,09000              3206
# 2             105,33750                            6,09000              3615
# 3             104,18530                            6,09000              4043
# 4             104,18530                            6,09000              4043
# ...                 ...                                ...               ...
# 81667         102,38920                            6,08000              3789
# 81668         101,23690                            6,09000              4217
# 81669         101,23690                            6,09000              4217
# 81670               NaN                                NaN               NaN
# 81671               NaN                                NaN               NaN
#
# 1     Единица измерения цены      Тип цены                   File
# 0             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 1             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 2             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 3             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# 4             Чистая цена в%  Индикативная   Price29_06_2021.xlsx
# ...                      ...           ...                    ...
# 81667         Чистая цена в%  Индикативная  Price05_01_21(1).xlsx
# 81668         Чистая цена в%  Индикативная  Price05_01_21(1).xlsx
# 81669         Чистая цена в%  Индикативная  Price05_01_21(1).xlsx
# 81670                  Тенге  Индикативная  Price05_01_21(1).xlsx
# 81671                  Тенге  Индикативная  Price05_01_21(1).xlsx
#
# [81672 rows x 11 columns]

# %%
# df = pd.DataFrame()
# for i in xlsx_files:
#     temp_df = pd.read_excel(r"C:\Users\Sultan\Downloads\Big Data downloads\Kase Zips" +'\\'+ i, engine='openpyxl')
#     try: 
#         headers = temp_df.iloc[1]
#         temp_df = temp_df[3:]
#         temp_df.columns = headers
#         temp_df['File Number'] = xlsx_files.index(i)
#         df = df.append(temp_df)
#     except (IndexError, AttributeError):
#         pass
